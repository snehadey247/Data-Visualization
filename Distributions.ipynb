# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Path of the file to read
iris_filepath = "iris.csv"

# Read the file into a variable iris_data
iris_data = pd.read_csv(iris_filepath) 

# Print the first 5 rows of the data
iris_data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ## Histograms

# %%
# Histogram 
sns.distplot(a=iris_data['petal.length'], kde=False)

# %% [markdown]
# ## Density plots

# %%
# KDE plot 
sns.kdeplot(data=iris_data['petal.length'], shade=True)

# %% [markdown]
# ## 2D KDE plots

# %%
# 2D KDE plot
sns.jointplot(x=iris_data['petal.length'], y=iris_data['sepal.width'], kind="kde")

# %% [markdown]
# ## Color-coded plots

# %%
# Paths of the files to read
iris_set_filepath = "iris_setosa.csv"
iris_ver_filepath = "iris_versicolor.csv"
iris_vir_filepath = "iris_virginica.csv"

# Read the files into variables 
iris_set_data = pd.read_csv(iris_set_filepath)
iris_ver_data = pd.read_csv(iris_ver_filepath)
iris_vir_data = pd.read_csv(iris_vir_filepath)

# Print the first 5 rows of the Iris versicolor data
iris_ver_data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width     variety
# 0           7.0          3.2           4.7          1.4  Versicolor
# 1           6.4          3.2           4.5          1.5  Versicolor
# 2           6.9          3.1           4.9          1.5  Versicolor
# 3           5.5          2.3           4.0          1.3  Versicolor
# 4           6.5          2.8           4.6          1.5  Versicolor

# %%
# Histograms for each species
sns.distplot(a=iris_set_data['petal.length'], label="Setosa", kde=False)
sns.distplot(a=iris_ver_data['petal.length'], label="Versicolor", kde=False)
sns.distplot(a=iris_vir_data['petal.length'], label="Virginica", kde=False)

# Add title
plt.title("Histogram of Petal Lengths, by Species")

# Force legend to appear
plt.legend()

# %%
# KDE plots for each species
sns.kdeplot(data=iris_set_data['petal.length'], label="Iris-setosa", shade=True)
sns.kdeplot(data=iris_ver_data['petal.length'], label="Iris-versicolor", shade=True)
sns.kdeplot(data=iris_vir_data['petal.length'], label="Iris-virginica", shade=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')
